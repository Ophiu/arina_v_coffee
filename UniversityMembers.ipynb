# %%
class Subject:
    pass

class Actions:
    pass

class Teacher(Actions):
    pass

class IvanIvanovich(Teacher):
    
    def __init__(self):
        self._post = 'Доктор наук'
        self._subjects = 'математический анализ, линейная алгебра'
        self._givinglectures = 'математический анализ'
        self._ratings = [5, 5, 5, 5, 5, 4, 5]
        self._name = 'Иванов Иван Иванович'
        
    def print_data(self):
        return self._name, self._subjects, self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k
    
    def print_givinglectures(self):
        return self._givinglectures

class VasilyVasilievich(Teacher):
    
    def __init__(self):
        self._post = 'Аспирант'
        self._subjects = 'математический анализ, линейная алгебра'
        self._givinglectures = '-'
        self._ratings = [4, 3, 5, 3]
        self._name = 'Васильев Василий Васильевич'
        
    def print_data(self):
        return self._name, self._subjects, self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k
    
    def print_givinglectures(self):
        return self._givinglectures
        
class PetrPetrovich(Teacher):
    def __init__(self):
        self._post = 'Профессор'
        self._subjects = 'математический анализ, линейная алгебра'
        self._givinglectures = 'линейная алгебра'
        self._ratings = [3, 3, 5, 3, 5, 2]
        self._name = 'Петров Петр Петрович'
        
    def print_data(self):
        return self._name, self._subjects, self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k
    
    def print_givinglectures(self):
        return self._givinglectures

class NewProfessor(Teacher):
    def __init__(self, post, name, ratings, givinglectures, subjects):
        self._post = post
        self._subjects = subjects
        self._givinglectures = givinglectures
        self._ratings = ratings
        self._name = name
        
    def print_data(self):
        return self._name, self._subjects, self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k
    
    def print_givinglectures(self):
        return self._givinglectures
    
def start_game():

    try:
        print('Добро пожаловать в университет!')
        n = True
        while n:
            print("Выберите действие: \n 1. Узнать данные о преподавателе. \n 2. Узнать средний балл студентов у преподавателя. \n 3. Узнать, какие лекции читает преподаватель. \n 4. Добавить нового преподавателя")
            answer1 = int(input())
            print("Выберите преподавателя: \n 1. Иванов И.И. \n 2. Васильев В.В. \n 3. Петров П.П.")
            answer2 = int(input())
            need = []
            if answer2 == 1:
                a = IvanIvanovich()
            if answer2 == 2:
                a = VasilyVasilievich()
            if answer2 == 3:
                a = PetrPetrovich()
            if answer1 == 1:
                b, c, d = a.print_data()
                e = ''
                if d != 'Аспирант':
                    e = 'Имеет право принимать зачеты и экзамены.'
                print(d, b + '. Преподаваемые предметы:', c + '.', e)
            if answer1 == 2:
                b = a.print_averange_rating()
                print(b)
            if answer1 == 3:
                b = a.print_givinglectures()
                if b == '-':
                    print("Этот преподаватель не читает лекций.")
                else:
                    print("Этот преподаватель читает лекции по предмету:", b + '.')
            print("Остались ли у Вас вопросы? \n 1. Да. \n 2. Нет.")
            answer3 = int(input())
            if answer1 == 4:
                print('Введите имя преподавателя')
                newname = input()
                print('Введите должность преподавателя')
                newpost = input()
                print('Введите преподаваемые преподавателем предметы')
                newsubjects = input()
                print('Введите препо')
                newname = input()
                print('Введите имя преподавателя')
                newname = input()
            if answer3 == 2:
                n = False
            else:
                  continue
            
    except EOFError:
        print('Поток ввода закончился. Извините, принимать ответы более невозможно.')

        
print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в университет!
# Выберите действие:
#  1. Узнать данные о преподавателе.
#  2. Узнать средний балл студентов у преподавателя.
#  3. Узнать, какие лекции читает преподаватель.
# 3
# Выберите преподавателя:
#  1. Иванов И.И.
#  2. Васильев В.В.
#  3. Петров П.П.
# 3
# Этот преподаватель читает лекции по предмету: линейная алгебра.
# Остались ли у Вас вопросы?
#  1. Да.
#  2. Нет.
# 1
# Выберите действие:
#  1. Узнать данные о преподавателе.
#  2. Узнать средний балл студентов у преподавателя.
#  3. Узнать, какие лекции читает преподаватель.
# 3
# Выберите преподавателя:
#  1. Иванов И.И.
#  2. Васильев В.В.
#  3. Петров П.П.
# 3
# Этот преподаватель читает лекции по предмету: линейная алгебра.
# Остались ли у Вас вопросы?
#  1. Да.
#  2. Нет.
# 2
