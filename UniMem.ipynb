# %%
class Attacker:
    _health = None
    _attack = None

    def attack(self, target):
        target._health -= self._attack
    
    def experience(self, target):
        target._experience = self._experience + 10

    def is_alive(self):
        return self._health >= 0


class Enemy(Attacker):
    pass


def generate_random_enemy():
    RandomEnemyType = choice(enemy_types)
    enemy = RandomEnemyType()
    return enemy


def generate_dragon_list(enemy_number):
    enemy_list = [generate_random_enemy() for i in range(enemy_number)]
    return enemy_list


class Dragon(Enemy):
    def set_answer(self, answer):
        self.__answer = answer

    def check_answer(self, answer):
        return answer == self.__answer


class GreenDragon(Dragon):
    def __init__(self):
        self._health = 100
        self._attack = 10
        self._name = 'зелёный дракон'

    def question(self):
        x = randint(1,100)
        y = randint(1,100)
        self.__quest = str(x) + '+' + str(y)
        self.set_answer(x + y)
        return self.__quest

    
class RedDragon(Dragon):
    def __init__(self):
        self._health = 100
        self._attack = 10
        self._name = 'красный дракон'

    def question(self):
        x = randint(1,100)
        y = randint(1,100)
        self.__quest = str(x) + '-' + str(y)
        self.set_answer(x - y)
        return self.__quest

    
class BlackDragon(Dragon):
    def __init__(self):
        self._health = 100
        self._attack = 10
        self._name = 'черный дракон'

    def question(self):
        x = randint(1,100)
        y = randint(1,100)
        self.__quest = str(x) + '*' + str(y)
        self.set_answer(x * y)
        return self.__quest

class TrollGuess(Dragon):
    def __init__(self):
        self._health = 0
        self._attack = 0
        self._name = 'тролль-угадайка'

    def question(self):
        x = randint(1, 5)
        self.__quest = 'Угадай число от 1 до 5'
        self.set_answer(x)
        return self.__quest
    
class PrimeTroll(Dragon):
    def __init__(self):
        self._health = 0
        self._attack = 10
        self._name = '"простой" тролль'

    def question(self):
        x = randint(1, 100)
        self.__quest = 'Простое ли это число ' + str(x) + '? Напишите 1, если число простое и 0 в противном случае.'
        if x in prime_numbers:
            self.set_answer(1)
        else:
            self.set_answer(0)
        return self.__quest


enemy_types = [GreenDragon, RedDragon, BlackDragon, TrollGuess, PrimeTroll]


class Hero(Attacker):
    def __init__(self, name):
        self.name = name  
        self._health = 100
        self._attack = 50
        self._experience = 0
        
        
def annoying_input_int(message =''):
    answer = None
    while answer == None:
        try:
            answer = int(input(message))
        except ValueError:
            print('Вы ввели недопустимые символы')
    return answer


def game_tournament(hero, dragon_list):
    for dragon in dragon_list:
        print('Вышел', dragon._name + '!')
        while dragon.is_alive() and hero.is_alive():
            print('Вопрос:', dragon.question())
            answer = annoying_input_int('Ответ: ')

            if dragon.check_answer(answer):
                hero.attack(dragon)
                hero.experience(hero)
                print('Верно! \n** противник кричит от боли **')
            else:
                dragon.attack(hero)
                print('Ошибка! \n** вам нанесён удар... **')
        if dragon.is_alive():
            break
        print(dragon._name, 'повержен!\n')

    if hero.is_alive():
        print('Поздравляем! Вы победили!')
        print('Ваш накопленный опыт:', hero._experience)
    else:
        print('К сожалению, Вы проиграли...')
        

def start_game():

    try:
        print('Добро пожаловать в арифметико-ролевую игру с драконами и троллями!')
        print('Представьтесь, пожалуйста: ', end = '')
        hero = Hero(input())

        dragon_number = 5
        dragon_list = generate_dragon_list(dragon_number)
        assert(len(dragon_list) == 5)
        print('У Вас на пути', dragon_number, 'врагов!')
        game_tournament(hero, dragon_list)

    except EOFError:
        print('Поток ввода закончился. Извините, принимать ответы более невозможно.')

        
print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-d5bda3300b09> in <module>
#      17
#      18 loop = asyncio.get_event_loop()
# ---> 19 loop.run_until_complete(main())
#      20 loop.close()
#
# ~/opt/anaconda3/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     568         future.add_done_callback(_run_until_complete_cb)
#     569         try:
# --> 570             self.run_forever()
#     571         except:
#     572             if new_task and future.done() and not future.cancelled():
#
# ~/opt/anaconda3/lib/python3.7/asyncio/base_events.py in run_forever(self)
#     523         self._check_closed()
#     524         if self.is_running():
# --> 525             raise RuntimeError('This event loop is already running')
#     526         if events._get_running_loop() is not None:
#     527             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Task A: Compute factorial(2)...
# Task B: Compute factorial(2)...
# Task C: Compute factorial(2)...
# Task A: factorial(2) = 2
# Task B: Compute factorial(3)...
# Task C: Compute factorial(3)...
# Task B: factorial(3) = 6
# Task C: Compute factorial(4)...
# Task C: factorial(4) = 24

# %%
class Subject:
    pass

class Actions:
    def add_rating(self, grade):
        self._ratings.append(grade)
    
    def find_out_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        
    def print_data(self):
        if self._post == 2:
            ar = 'Лектор, доктор наук'
            br = 'Имеет право принимать зачеты и экзамены.'
        if self._post == 1:
            ar = 'Профессор'
            br = 'Имеет право принимать зачеты и экзамены.'
        if self._post == 0:
            ar = 'Аспирант'
            br = ''
        return ar + self._name + br

class Teacher(Actions):
    pass

class IvanIvanovich(Teacher):
    def __init__(self):
        self._post = 2
        self._ratings = [5, 5, 5, 5, 5, 4, 5]
        self._name = 'Иванов Иван Иванович'

class VasilyVasilievich(Teacher):
    def __init__(self):
        self._post = 0
        self._ratings = [4, 3, 5, 3]
        self._name = 'Васильев Василий Васильевич'
        
teacher_types = [IvanIvanovich, VasilyVasilievich]
    
def start_game():

    try:
        print('Добро пожаловать в университет!')
        print("Выберите действие: \n 1. Узнать данные о преподавателе. \n 2. Узнать средний балл студентов у преподавателя. \n 3. Добавить оценку.")
        answer1 = int(input())
        print("Выберите преподавателя: \n 1. Иванов И.И. \n 2. Васильев В.В.:")
        answer2 = int(input())
        need = []
        if answer1 == 1:
            if answer2 == 1:
                a = teacher_types[0]
                print(a)
                need.append(a)
                for teacher in need:
                    print(teacher.print_data(IvanIvanovich))
              
                  
            
    except EOFError:
        print('Поток ввода закончился. Извините, принимать ответы более невозможно.')

        
print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в университет!
# Выберите действие:
#  1. Узнать данные о преподавателе.
#  2. Узнать средний балл студентов у преподавателя.
#  3. Добавить оценку.
# 1
# Выберите преподавателя:
#  1. Иванов И.И.
#  2. Васильев В.В.:
# 1
# <class '__main__.IvanIvanovich'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-be18dd404e16> in <module>
#      65
#      66 if __name__ == '__main__':
# ---> 67     start_game()
#
# <ipython-input-15-be18dd404e16> in start_game()
#      54                 need.append(a)
#      55                 for teacher in need:
# ---> 56                     print(teacher.print_data(IvanIvanovich))
#      57
#      58
#
# <ipython-input-15-be18dd404e16> in print_data(self)
#      11
#      12     def print_data(self):
# ---> 13         if self._post == 2:
#      14             ar = 'Лектор, доктор наук'
#      15             br = 'Имеет право принимать зачеты и экзамены.'
#
# AttributeError: type object 'IvanIvanovich' has no attribute '_post'

# %% [markdown]
# #
