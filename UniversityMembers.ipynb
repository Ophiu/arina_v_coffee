# %%
class Subject:
    pass

class Actions:
    _name = None
    _post = None
    
    def add_rating(self, grade):
        self._ratings.append(grade)
    
    def find_out_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        
    #def print_data(self):
        #if self._post == '2':
            #print('Лектор, доктор наук' + self._name + 'Имеет право принимать зачеты и экзамены.')
        #if self._post == 1:
            #return 'Профессор' + self._name + 'Имеет право принимать зачеты и экзамены.'
        #if self._post == 0:
            #return 'Аспирант' + self._name

class Teacher(Actions):
    pass

class IvanIvanovich(Teacher):
    
    def __init__(self):
        self._post = '2'
        self._ratings = [5, 5, 5, 5, 5, 4, 5]
        self._name = 'Иванов Иван Иванович'
        
    def print_data(self):
        return self._name

class VasilyVasilievich(Teacher):
    def __init__(self):
        self._post = 0
        self._ratings = [4, 3, 5, 3]
        self._name = 'Васильев Василий Васильевич'
        
teacher_types = [IvanIvanovich, VasilyVasilievich]
    
def start_game():

    try:
        print('Добро пожаловать в университет!')
        print("Выберите действие: \n 1. Узнать данные о преподавателе. \n 2. Узнать средний балл студентов у преподавателя. \n 3. Добавить оценку.")
        answer1 = int(input())
        print("Выберите преподавателя: \n 1. Иванов И.И. \n 2. Васильев В.В.:")
        answer2 = int(input())
        need = []
        if answer1 == 1:
            if answer2 == 1:
                a = teacher_types[0]
                print(a)
                need.append(a)
                for teacher in need:
                    print('Лектор, доктор наук', teacher.print_data(IvanIvanovich), '. Имеет право принимать зачеты и экзамены.')
              
                  
            
    except EOFError:
        print('Поток ввода закончился. Извините, принимать ответы более невозможно.')

        
print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в университет!
# Выберите действие:
#  1. Узнать данные о преподавателе.
#  2. Узнать средний балл студентов у преподавателя.
#  3. Добавить оценку.
# 1
# Выберите преподавателя:
#  1. Иванов И.И.
#  2. Васильев В.В.:
# 1
# <class '__main__.IvanIvanovich'>
# Лектор, доктор наук None . Имеет право принимать зачеты и экзамены.
