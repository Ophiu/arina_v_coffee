# %%
class Subject:
    pass

class Actions:
    pass
class Teacher(Actions):
    pass

class IvanIvanovich(Teacher):
    
    def __init__(self):
        self._post = 'Лектор, доктор наук'
        self._ratings = [5, 5, 5, 5, 5, 4, 5]
        self._name = 'Иванов Иван Иванович'
        
    def print_data(self):
        return self._name
    
    def print_post(self):
        return self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k

class VasilyVasilievich(Teacher):
    def __init__(self):
        self._post = 'Аспирант'
        self._ratings = [4, 3, 5, 3]
        self._name = 'Васильев Василий Васильевич'
        
    def print_data(self):
        return self._name
    
    def print_post(self):
        return self._post
    
    def print_averange_rating(self):
        s = sum(self._ratings)
        k = len(self._ratings)
        return s/k
        
teacher_types = [IvanIvanovich, VasilyVasilievich]
    
def start_game():

    try:
        print('Добро пожаловать в университет!')
        print("Выберите действие: \n 1. Узнать данные о преподавателе. \n 2. Узнать средний балл студентов у преподавателя.")
        answer1 = int(input())
        print("Выберите преподавателя: \n 1. Иванов И.И. \n 2. Васильев В.В.:")
        answer2 = int(input())
        need = []
        if answer2 == 1:
            a = IvanIvanovich()
        if answer2 == 2:
            a = VasilyVasilievich()
        if answer1 == 1:
            b = a.print_data()
            c = a.print_post()
            d = ''
            if c != 'Аспирант':
                d = 'Имеет право принимать зачеты и экзамены.'
            print(c, b + '.', d)
        if answer1 == 2:
            b = a.print_averange_rating()
            print(b)
                  
            
    except EOFError:
        print('Поток ввода закончился. Извините, принимать ответы более невозможно.')

        
print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в университет!
# Выберите действие:
#  1. Узнать данные о преподавателе.
#  2. Узнать средний балл студентов у преподавателя.
#  3. Добавить оценку.
# 2
# Выберите преподавателя:
#  1. Иванов И.И.
#  2. Васильев В.В.:
# 1
# 4.857142857142857
